# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunK-ML/FULL---Fraud-Email---DataSet/blob/main/Fraud_Email.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Enron Fraud Email Dataset**

# %% [markdown]
# https://www.kaggle.com/datasets/advaithsrao/enron-fraud-email-dataset

# %%
import pandas as pd
df = pd.read_csv("/content/Enron Fraud Email Dataset.csv")
df
# Out:
#      Folder-User   Folder-Name                                     Message-ID  \
# 0        maildir      farmer-d  <14765870.1075854059714.JavaMail.evans@thyme>
# 1        maildir      weldon-c  <27248880.1075851688709.JavaMail.evans@thyme>
# 2        maildir      farmer-d  <30121413.1075860776823.JavaMail.evans@thyme>
# 3        maildir  shackleton-s  <11638341.1075844504953.JavaMail.evans@thyme>
# 4        maildir      cuilla-m   <2346151.1075858078353.JavaMail.evans@thyme>
# ...          ...           ...                                            ...
# 8364     maildir      guzman-m  <27755095.1075840713620.JavaMail.evans@thyme>
# 8365     maildir       parks-j  <15698374.1075841363764.JavaMail.evans@thyme>
# 8366     maildir   hernandez-j  <18812457.1075851845159.JavaMail.evans@thyme>
# 8367     maildir         lay-k  <19182723.1075860836364.JavaMail.evans@thyme>
# 8368     maildir       lewis-a   <7704916.1075857103075.JavaMail.evans@thyme>
#
#                                        Date  \
# 0      Tue, 7 Mar 2000 11:52:00 -0800 (PST)
# 1      Tue, 6 Feb 2001 07:29:00 -0800 (PST)
# 2     Wed, 18 Jul 2001 08:34:29 -0700 (PDT)
# 3     Mon, 10 Jul 2000 06:38:00 -0700 (PDT)
# 4     Wed, 15 Nov 2000 03:19:00 -0800 (PST)
# ...                                     ...
# 8364   Mon, 5 Mar 2001 18:39:00 -0800 (PST)
# 8365  Thu, 28 Mar 2002 05:49:30 -0800 (PST)
# 8366  Tue, 13 Feb 2001 02:39:00 -0800 (PST)
# 8367  Wed, 28 Nov 2001 15:27:23 -0800 (PST)
# 8368  Mon, 11 Dec 2000 03:23:00 -0800 (PST)
#
#                                           From  \
# 0                lyris@listserv.augusthome.com
# 1                scott.joyce@bankofamerica.com
# 2              customer_service@footlocker.com
# 3                       joel.ephross@enron.com
# 4                     support@imagestation.com
# ...                                        ...
# 8364                      pete.davis@enron.com
# 8365                      davidflowers@txu.com
# 8366                sandra.mcnichols@enron.com
# 8367                  will.reed@techforall.org
# 8368  1.11176403.999@multexinvestornetwork.com
#
#                                                      To  \
# 0                                daren.farmer@enron.com
# 1                            v.charles.weldon@enron.com
# 2                                     dfarmer@enron.com
# 3     jason.peters@enron.com, sarah.wesner@enron.com...
# 4                               martin.cuilla@enron.com
# ...                                                 ...
# 8364                               pete.davis@enron.com
# 8365                               davidflowers@txu.com
# 8366  carolyn.gilley@enron.com, leslie.smith@enron.c...
# 8367  syeager@fyi-net.com, pdouglas@salus.net, jhdun...
# 8368                               alewis@ect.enron.com
#
#                                                 Subject Mime-Version  \
# 0                       Welcome to WoodworkingTips.com!            1
# 1                                            RE: Friday            1
# 2                Order Confirmation from Footlocker.com            1
# 3                                  Re: Revised Guaranty            1
# 4                       Welcome to Sony's ImageStation!            1
# ...                                                 ...          ...
# 8364  Start Date: 3/6/01; HourAhead hour: 3;  <CODES...            1
# 8365  TXU LSP Available Capacity - Capacity availabl...            1
# 8366                        Thank You Birthday Planners            1
# 8367  Enron Situation and Technology For All: A Note...            1
# 8368                               Exclusive Invitation            1
#
#                             Content-Type Content-Transfer-Encoding  ... Re  \
# 0           text/plain; charset=us-ascii                      7bit  ...
# 1           text/plain; charset=us-ascii                      7bit  ...
# 2     text/plain; charset=ANSI_X3.4-1968                      7bit  ...
# 3           text/plain; charset=us-ascii                      7bit  ...
# 4           text/plain; charset=us-ascii                      7bit  ...
# ...                                  ...                       ...  ... ..
# 8364        text/plain; charset=us-ascii                      7bit  ...
# 8365        text/plain; charset=us-ascii                      7bit  ...
# 8366        text/plain; charset=us-ascii                      7bit  ...
# 8367        text/plain; charset=us-ascii                      7bit  ...
# 8368        text/plain; charset=us-ascii                      7bit  ...
#
#           Source                                            Mail-ID  \
# 0     Enron Data  15a4738ea7e2f12d79fcaf292122c61efc964d393ebaae...
# 1     Enron Data  c982b85fc76f105449624867c4838b9fab93de8d8930fe...
# 2     Enron Data  8651650eaff548c8eb7aabbabd08a1c4af5a4445909640...
# 3     Enron Data  3aa9e2aea2a139e36c02fa05de6b2a36eb51c9f1915445...
# 4     Enron Data  25c0088a13689196d433e2f7e3b1524c18102e6c2555c0...
# ...          ...                                                ...
# 8364  Enron Data  0dcea3742e6faad9bad1d1ab0aa781fd0f2a445fc4b8ad...
# 8365  Enron Data  2e36f64da7a7db671354040ef7e23998b4e7030bc50803...
# 8366  Enron Data  07e8f7befa0b96d1e160a8d7c57d308e537b849c771699...
# 8367  Enron Data  5f5d150886edd526482e00edcabb60a566c0fb1b8bff53...
# 8368  Enron Data  c93be249b0d29132113f886b8e5aaeced9e55cfaa33d27...
#
#      POI-Present Suspicious-Folders Sender-Type Unique-Mails-From-Sender  \
# 0          FALSE              FALSE    External                        2
# 1          FALSE              FALSE    External                        2
# 2          FALSE              FALSE    External                        3
# 3          FALSE              FALSE    Internal                       36
# 4          FALSE              FALSE    External                        1
# ...          ...                ...         ...                      ...
# 8364       FALSE              FALSE    Internal                     3621
# 8365       FALSE              FALSE    External                       12
# 8366       FALSE              FALSE    Internal                       25
# 8367       FALSE              FALSE    External                        7
# 8368       FALSE              FALSE    External                        1
#
#      Low-Comm Contains-Reply-Forwards Label
# 0        TRUE                   FALSE     0
# 1        TRUE                    TRUE     0
# 2        TRUE                   FALSE     1
# 3       FALSE                   FALSE     0
# 4        TRUE                   FALSE     1
# ...       ...                     ...   ...
# 8364    FALSE                   FALSE     0
# 8365    FALSE                   FALSE     0
# 8366    FALSE                   FALSE     0
# 8367    FALSE                   FALSE     0
# 8368     TRUE                   FALSE     1
#
# [8369 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Folder-User                8348 non-null   object
#  1   Folder-Name                8348 non-null   object
#  2   Message-ID                 8348 non-null   object
#  3   Date                       8348 non-null   object
#  4   From                       8348 non-null   object
#  5   To                         8348 non-null   object
#  6   Subject                    8057 non-null   object
#  7   Mime-Version               8348 non-null   object
#  8   Content-Type               8348 non-null   object
#  9   Content-Transfer-Encoding  8348 non-null   object
#  10  X-From                     8348 non-null   object
#  11  X-To                       8220 non-null   object
#  12  X-cc                       1592 non-null   object
#  13  X-bcc                      25 non-null     object
#  14  X-Folder                   8347 non-null   object
#  15  X-Origin                   8347 non-null   object
#  16  X-FileName                 8290 non-null   object
#  17  Body                       8347 non-null   object
#  18  Cc                         8327 non-null   object
#  19  Bcc                        8327 non-null   object
#  20  Time                       8327 non-null   object
#  21  Attendees                  8327 non-null   object
#  22  Re                         8327 non-null   object
#  23  Source                     8327 non-null   object
#  24  Mail-ID                    8327 non-null   object
#  25  POI-Present                8327 non-null   object
#  26  Suspicious-Folders         8327 non-null   object
#  27  Sender-Type                8327 non-null   object
#  28  Unique-Mails-From-Sender   8327 non-null   object
#  29  Low-Comm                   8327 non-null   object
#  30  Contains-Reply-Forwards    8326 non-null   object
#  31  Label                      8326 non-null   object
# dtypes: object(32)
# memory usage: 2.0+ MB

# %%
df.isna().sum()
# Out:
# Folder-User                    21
# Folder-Name                    21
# Message-ID                     21
# Date                           21
# From                           21
# To                             21
# Subject                       312
# Mime-Version                   21
# Content-Type                   21
# Content-Transfer-Encoding      21
# X-From                         21
# X-To                          149
# X-cc                         6777
# X-bcc                        8344
# X-Folder                       22
# X-Origin                       22
# X-FileName                     79
# Body                           22
# Cc                             42
# Bcc                            42
# Time                           42
# Attendees                      42
# Re                             42
# Source                         42
# Mail-ID                        42
# POI-Present                    42
# Suspicious-Folders             42
# Sender-Type                    42
# Unique-Mails-From-Sender       42
# Low-Comm                       42
# Contains-Reply-Forwards        43
# Label                          43
# dtype: int64
